# %% [markdown]
# <a href="https://colab.research.google.com/github/denizbaris/Data-with-Python/blob/main/DAwPython9_datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Text & Time Methods

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df[df.sex.str.contains('female')]   #string method
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 8           1       3  female  27.0  ...   NaN  Southampton    yes  False
# 9           1       2  female  14.0  ...   NaN    Cherbourg    yes  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 882         0       3  female  22.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
#
# [314 rows x 15 columns]

# %%
df[df.sex == 'female']
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 8           1       3  female  27.0  ...   NaN  Southampton    yes  False
# 9           1       2  female  14.0  ...   NaN    Cherbourg    yes  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 882         0       3  female  22.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
#
# [314 rows x 15 columns]

# %%
df.sex = df.sex.str.upper()   #upper islemini her bir elemana uygula ve geri dondur
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df[df.sex =='female']['sex'] = df[df.sex == 'female']['sex'].str.upper()
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df = df.replace('male','MALE')
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    MALE  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    MALE  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    MALE  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    MALE  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df['class'] = df['class'].str.swapcase()   #buyukkeri kucuk, kucukleri buyuk yapiyor swapcase
df['class']
# Out:
# 0       tHIRD
# 1       fIRST
# 2       tHIRD
# 3       fIRST
# 4       tHIRD
#         ...
# 886    sECOND
# 887     fIRST
# 888     tHIRD
# 889     fIRST
# 890     tHIRD
# Name: class, Length: 891, dtype: object

# %%
df['age'].astype('string').str.isnumeric()   #astype kullandik
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     <NA>
# 889    False
# 890    False
# Name: age, Length: 891, dtype: boolean

# %%
df.age = df.age.replace(np.nan,'Unknown')
df.age.value_counts()
# Out:
# Unknown    177
# 24.0        30
# 22.0        27
# 18.0        26
# 28.0        25
#           ...
# 14.5         1
# 23.5         1
# 20.5         1
# 0.67         1
# 80.0         1
# Name: age, Length: 89, dtype: int64

# %%
df
# Out:
#      survived  pclass     sex      age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE       22  ...   NaN  Southampton     no  False
# 1           1       1  female       38  ...     C    Cherbourg    yes  False
# 2           1       3  female       26  ...   NaN  Southampton    yes   True
# 3           1       1  female       35  ...     C  Southampton    yes  False
# 4           0       3    MALE       35  ...   NaN  Southampton     no   True
# ..        ...     ...     ...      ...  ...   ...          ...    ...    ...
# 886         0       2    MALE       27  ...   NaN  Southampton     no   True
# 887         1       1  female       19  ...     B  Southampton    yes   True
# 888         0       3  female  Unknown  ...   NaN  Southampton     no  False
# 889         1       1    MALE       26  ...     C    Cherbourg    yes   True
# 890         0       3    MALE       32  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.embark_town.str.contains('Cherbourg')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.fillna(df.embark_town.mode()[0], inplace=True)

# %%
df[df.embark_town.str.startswith('Ch')]
# Out:
#      survived  pclass     sex      age  ...  deck  embark_town  alive  alone
# 1           1       1  female       38  ...     C    Cherbourg    yes  False
# 9           1       2  female       14  ...   NaN    Cherbourg    yes  False
# 19          1       3  female  Unknown  ...   NaN    Cherbourg    yes   True
# 26          0       3    MALE  Unknown  ...   NaN    Cherbourg     no   True
# 30          0       1    MALE       40  ...   NaN    Cherbourg     no   True
# ..        ...     ...     ...      ...  ...   ...          ...    ...    ...
# 866         1       2  female       27  ...   NaN    Cherbourg    yes  False
# 874         1       2  female       28  ...   NaN    Cherbourg    yes  False
# 875         1       3  female       15  ...   NaN    Cherbourg    yes   True
# 879         1       1  female       56  ...     C    Cherbourg    yes  False
# 889         1       1    MALE       26  ...     C    Cherbourg    yes   True
#
# [168 rows x 15 columns]

# %%
df.age.astype("string").str.find('Unknown')   #find fonksiyonu bulmazsa -1 bulursa 0
# Out:
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 886    -1
# 887    -1
# 888     0
# 889    -1
# 890    -1
# Name: age, Length: 891, dtype: Int64

# %%
df.embark_town.str.find('Queenstown')
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 886   -1
# 887   -1
# 888   -1
# 889   -1
# 890    0
# Name: embark_town, Length: 891, dtype: int64

# %% [markdown]
# ##DATETIME

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.year = pd.to_datetime(df.year)

# %%
df.year
# Out:
# 0     1970-01-01 00:00:00.000001949
# 1     1970-01-01 00:00:00.000001949
# 2     1970-01-01 00:00:00.000001949
# 3     1970-01-01 00:00:00.000001949
# 4     1970-01-01 00:00:00.000001949
#                    ...
# 139   1970-01-01 00:00:00.000001960
# 140   1970-01-01 00:00:00.000001960
# 141   1970-01-01 00:00:00.000001960
# 142   1970-01-01 00:00:00.000001960
# 143   1970-01-01 00:00:00.000001960
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
df.year.dt.year                          #string method str datetime method dt
# Out:
# 0      1970
# 1      1970
# 2      1970
# 3      1970
# 4      1970
#        ...
# 139    1970
# 140    1970
# 141    1970
# 142    1970
# 143    1970
# Name: year, Length: 144, dtype: int64

# %%
df.year.value_counts()
# Out:
# 1970-01-01 00:00:00.000001960    12
# 1970-01-01 00:00:00.000001959    12
# 1970-01-01 00:00:00.000001958    12
# 1970-01-01 00:00:00.000001957    12
# 1970-01-01 00:00:00.000001956    12
# 1970-01-01 00:00:00.000001955    12
# 1970-01-01 00:00:00.000001954    12
# 1970-01-01 00:00:00.000001953    12
# 1970-01-01 00:00:00.000001952    12
# 1970-01-01 00:00:00.000001951    12
# 1970-01-01 00:00:00.000001950    12
# 1970-01-01 00:00:00.000001949    12
# Name: year, dtype: int64

# %%
df.year.unique()
# Out:
# array(['1970-01-01T00:00:00.000001949', '1970-01-01T00:00:00.000001950',
#        '1970-01-01T00:00:00.000001951', '1970-01-01T00:00:00.000001952',
#        '1970-01-01T00:00:00.000001953', '1970-01-01T00:00:00.000001954',
#        '1970-01-01T00:00:00.000001955', '1970-01-01T00:00:00.000001956',
#        '1970-01-01T00:00:00.000001957', '1970-01-01T00:00:00.000001958',
#        '1970-01-01T00:00:00.000001959', '1970-01-01T00:00:00.000001960'],
#       dtype='datetime64[ns]')

# %%
ders_bitti = datetime.now()
current_date
# Out:
# datetime.datetime(2021, 10, 9, 9, 45, 20, 869042)

# %%
current_date.strftime('%d'+' '+'%B'+' '+'%Y')
# Out:
# '09 October 2021'

# %%
date1 = current_date.strftime('%d %b %y')
date1
# Out:
# '09 Oct 21'

# %%
from datetime import timedelta

# %%
current_date+timedelta(weeks=2)
# Out:
# datetime.datetime(2021, 10, 23, 9, 45, 20, 869042)

# %%
(current_date.today()-timedelta(days=149)).strftime('%d %B %Y')
# Out:
# '13 May 2021'

# %% [markdown]
# ##data input output

# %%
df = pd.read_csv('example.csv')#,usecols = ['a','b'] eklersen a ve b columnlarini alir

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
titanic = pd.read_csv('titanic_train.csv', sep = ',')
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df = pd.read_excel('Excel_Sample.xlsx')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('excel1.xlsx', sheet_name= 'sh1', index=False)
df.to_excel('excel2.xlsx', sheet_name= 'sh2')

# %%
df = pd.read_excel('excel1.xlsx', sheet_name='sh1')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
with pd.ExcelWriter('combined_xlsx') as writer :
  df.to_excel(writer, sheet_name='sh1', index=False)
  df.to_excel(writer, sheet_name='sh2', index=True)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     632                 try:
# --> 633                     engine = config.get_option(f"io.excel.{ext}.writer")
#     634                     if engine == "auto":
#
# /usr/local/lib/python3.7/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#
# /usr/local/lib/python3.7/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     104 def _get_option(pat: str, silent: bool = False):
# --> 105     key = _get_single_key(pat, silent)
#     106
#
# /usr/local/lib/python3.7/dist-packages/pandas/_config/config.py in _get_single_key(pat, silent)
# ...

# %%
with pd.ExcelWriter('combined_dfs.xlsx') as writer:
    df.to_excel(writer, sheet_name='sh1', index=False)
    df.to_excel(writer, sheet_name='sh2',index=True)

# %%
pd.read_excel("combined_dfs.xlsx", sheet_name="sh1")
pd.read_excel("combined_dfs.xlsx", sheet_name="sh2")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df2 = pd.read_html('https://www.bbc.com/news/world-51235105')

# %%
df2
# Out:
# [              Country  Deaths  ...  New Cases  0  10  100  1k  10k  **  Unnamed: 5
#  0                  US  706709  ...                                 NaN         NaN
#  1              Brazil  599810  ...                                 NaN         NaN
#  2               India  450127  ...                                 NaN         NaN
#  3              Mexico  281121  ...                                 NaN         NaN
#  4              Russia  209752  ...                                 NaN         NaN
#  ..                ...     ...  ...                                 ...         ...
#  213             Palau       0  ...                                 NaN         NaN
#  214  Marshall Islands       0  ...                                 NaN         NaN
#  215             Samoa       0  ...                                 NaN         NaN
#  216          Kiribati       0  ...                                 NaN         NaN
# ...

# %%
df2[0].to_html('simple.html', index=False)

# %%
pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine('sqlite:///:memory:')

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/World_population')

# %%
tables
# Out:
# [        World population (millions, UN estimates)[14]  ...
#                                                      #  ...                                            2030[A]
#  0                                                   1  ...                                               1416
#  1                                                   2  ...                                               1528
#  2                                                   3  ...                                                356
#  3                                                   4  ...                                                295
#  4                                                   5  ...                                                245
#  5                                                   6  ...                                                228
#  6                                                   7  ...                                                263
# ...

# %%
pop=tables[5]
pop
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   171490000     143998              1191
# 2     3      Lebanon     6856000      10452               656
# 3     4       Taiwan    23604000      36193               652
# 4     5  South Korea    51781000      99538               520
# 5     6       Rwanda    12374000      26338               470
# 6     7        Haiti    11578000      27065               428
# 7     8  Netherlands    17640000      41526               425
# 8     9       Israel     9410000      22072               426
# 9    10        India  1382840000    3287240               421

# %%
pop.to_sql(name='populations', con=temp_db)

# %%
temp_db.table_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['populations']

# %%
pd.read_sql(sql='populations', con=temp_db)
# Out:
#    index  Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0      0     1    Singapore     5704000        710              8033
# 1      1     2   Bangladesh   171490000     143998              1191
# 2      2     3      Lebanon     6856000      10452               656
# 3      3     4       Taiwan    23604000      36193               652
# 4      4     5  South Korea    51781000      99538               520
# 5      5     6       Rwanda    12374000      26338               470
# 6      6     7        Haiti    11578000      27065               428
# 7      7     8  Netherlands    17640000      41526               425
# 8      8     9       Israel     9410000      22072               426
# 9      9    10        India  1382840000    3287240               421

# %%
pd.read_sql_query(sql='select Country, Population from populations', con=temp_db)
# Out:
#        Country  Population
# 0    Singapore     5704000
# 1   Bangladesh   171490000
# 2      Lebanon     6856000
# 3       Taiwan    23604000
# 4  South Korea    51781000
# 5       Rwanda    12374000
# 6        Haiti    11578000
# 7  Netherlands    17640000
# 8       Israel     9410000
# 9        India  1382840000
